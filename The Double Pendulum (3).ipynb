# %%
import sympy as sp
import numpy as np
from matplotlib import pyplot as plt
sp.init_printing()

# %% [markdown]
# ### Defining Symbols

# %%
l1,l2,m1,m2,g,t = sp.symbols('l1,l2,m1,m2,g,t')

# %% [markdown]
# ### Defining the Functions

# %%
phi1 = sp.Function(r'\phi_1')
phi2 = sp.Function(r'\phi_2')
phi1_d = sp.diff(phi1(t), t)
phi2_d = sp.diff(phi2(t), t)
phi1_dd = sp.diff(phi1_d, t)
phi2_dd = sp.diff(phi2_d, t)

# %% [markdown]
# ### Generalised coordinates

# %%
x1 = l1*sp.cos(phi1(t))
x2 = x1 + l2*sp.cos(phi2(t))
y1 = l1*sp.sin(phi1(t))
y2 = y1 + l2*sp.sin(phi2(t))
x1d = sp.diff(x1, t)
x2d = sp.diff(x2, t)
y1d = sp.diff(y1, t)
y2d = sp.diff(y2, t)

# %% [markdown]
# ### Defining the Lagrangian

# %%
T = 1/2*m1*(x1d**2 + y1d**2) + 1/2*m2*(x2d**2 + y2d**2)
V = -m1*g*y1 - m2*g*y2
L = T - V
L
# Out:
#                                                                             ⎛
#                                                                             ⎜
# g⋅l₁⋅m₁⋅sin(\phi₁(t)) + g⋅m₂⋅(l₁⋅sin(\phi₁(t)) + l₂⋅sin(\phi₂(t))) + 0.5⋅m₁⋅⎜l
#                                                                             ⎝
#
#                                 2                                    2⎞
#  2    2           ⎛d           ⎞      2    2           ⎛d           ⎞ ⎟
# ₁ ⋅sin (\phi₁(t))⋅⎜──(\phi₁(t))⎟  + l₁ ⋅cos (\phi₁(t))⋅⎜──(\phi₁(t))⎟ ⎟ + 0.5⋅
#                   ⎝dt          ⎠                       ⎝dt          ⎠ ⎠
#
#    ⎛                                                                 2
#    ⎜⎛                   d                               d           ⎞    ⎛
# m₂⋅⎜⎜- l₁⋅sin(\phi₁(t))⋅──(\phi₁(t)) - l₂⋅sin(\phi₂(t))⋅──(\phi₂(t))⎟  + ⎜l₁⋅c
#    ⎝⎝                   dt                              dt          ⎠    ⎝
#
#                                                           2⎞
#              d                               d           ⎞ ⎟
# os(\phi₁(t))⋅──(\phi₁(t)) + l₂⋅cos(\phi₂(t))⋅──(\phi₂(t))⎟ ⎟
#              dt                              dt          ⎠ ⎠

# %% [markdown]
# ### Defining the Euler-Lagrange Equations

# %%
EL1 = sp.diff(L, phi1(t)) - sp.diff(sp.diff(L, phi1_d), t).simplify()
EL2 = sp.diff(L, phi2(t)) - sp.diff(sp.diff(L, phi2_d), t).simplify()
EL2
# Out:
#                               ⎛                                            2
#                               ⎜                              ⎛d           ⎞
# g⋅l₂⋅m₂⋅cos(\phi₂(t)) - l₂⋅m₂⋅⎜- l₁⋅sin(\phi₁(t) - \phi₂(t))⋅⎜──(\phi₁(t))⎟  +
#                               ⎜                              ⎝dt          ⎠
#                               ⎝
#
#
#                              d            d
#  l₁⋅sin(\phi₁(t) - \phi₂(t))⋅──(\phi₁(t))⋅──(\phi₂(t)) + l₁⋅cos(\phi₁(t) - \ph
#                              dt           dt
#
#
#          2                  2          ⎞
#         d                  d           ⎟          ⎛       ⎛
# i₂(t))⋅───(\phi₁(t)) + l₂⋅───(\phi₂(t))⎟ + 0.5⋅m₂⋅⎜- 2⋅l₂⋅⎜- l₁⋅sin(\phi₁(t))⋅
#          2                  2          ⎟          ⎝       ⎝
#        dt                 dt           ⎠
#
#
# d                               d           ⎞               d
# ──(\phi₁(t)) - l₂⋅sin(\phi₂(t))⋅──(\phi₂(t))⎟⋅cos(\phi₂(t))⋅──(\phi₂(t)) - 2⋅l
# dt                              dt          ⎠               dt
#
#
#
#   ⎛                 d                               d           ⎞
# ₂⋅⎜l₁⋅cos(\phi₁(t))⋅──(\phi₁(t)) + l₂⋅cos(\phi₂(t))⋅──(\phi₂(t))⎟⋅sin(\phi₂(t)
#   ⎝                 dt                              dt          ⎠
#
#
#
#   d           ⎞
# )⋅──(\phi₂(t))⎟
#   dt          ⎠

# %% [markdown]
# ### Obtaining the Equations of Motion of Both Arms

# %%
sols = sp.solve([EL1, EL2], (phi1_dd, phi2_dd), 
                simplify = False, rational = False)
sols[phi1_dd]
# Out:
#
#
#
#                  1.0⋅g⋅m₁⋅cos(\phi₁(t))                         g⋅m₂⋅cos(\phi₁
# ─────────────────────────────────────────────────────── - ────────────────────
#                      2
# 1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₁⋅m₂   1.0⋅l₁⋅m₁ - l₁⋅m₂⋅co
#
#
#
#
# (t) - \phi₂(t))⋅cos(\phi₂(t))                          1.0⋅g⋅m₂⋅cos(\phi₁(t))
# ─────────────────────────────────── + ────────────────────────────────────────
#  2                                                         2
# s (\phi₁(t) - \phi₂(t)) + 1.0⋅l₁⋅m₂   1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(
#
#
#                                                                           ⎛d
#                   l₁⋅m₂⋅sin(\phi₁(t) - \phi₂(t))⋅cos(\phi₁(t) - \phi₂(t))⋅⎜──(
#                                                                           ⎝dt
# ─────────────── - ────────────────────────────────────────────────────────────
#                                                2
# t)) + 1.0⋅l₁⋅m₂           1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₁
#
#           2
#          ⎞                                                                d
# \phi₁(t))⎟    1.0⋅l₁⋅m₂⋅sin(\phi₁(t) - \phi₂(t))⋅cos(\phi₁(t) - \phi₂(t))⋅──(\
#          ⎠                                                                dt
# ─────────── + ────────────────────────────────────────────────────────────────
#                                                   2
# ⋅m₂                          1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0
#
#
#          d
# phi₁(t))⋅──(\phi₂(t))   l₁⋅m₂⋅sin(\phi₁(t))⋅cos(\phi₁(t) - \phi₂(t))⋅cos(\phi₂
#          dt
# ───────────────────── - ──────────────────────────────────────────────────────
#                                                            2
# ⋅l₁⋅m₂                                1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(
#
#
#      d            d
# (t))⋅──(\phi₁(t))⋅──(\phi₂(t))   1.0⋅l₁⋅m₂⋅sin(\phi₂(t))⋅cos(\phi₁(t) - \phi₂(
#      dt           dt
# ────────────────────────────── + ─────────────────────────────────────────────
#                                                                       2
# t)) + 1.0⋅l₁⋅m₂                                  1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(
#
#
#                   d            d
# t))⋅cos(\phi₁(t))⋅──(\phi₁(t))⋅──(\phi₂(t))   1.0⋅l₂⋅m₂⋅sin(\phi₁(t) - \phi₂(t
#                   dt           dt
# ─────────────────────────────────────────── + ────────────────────────────────
#                                                                      2
# t) - \phi₂(t)) + 1.0⋅l₁⋅m₂                      1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t
#
#
#    d            d                                                  ⎛d
# ))⋅──(\phi₁(t))⋅──(\phi₂(t))        l₂⋅m₂⋅sin(\phi₁(t) - \phi₂(t))⋅⎜──(\phi₂(t
#    dt           dt                                                 ⎝dt
# ──────────────────────────── - ───────────────────────────────────────────────
#                                                     2
# ) - \phi₂(t)) + 1.0⋅l₁⋅m₂      1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1
#
#    2
#   ⎞                                          d            d
# ))⎟        l₂⋅m₂⋅sin(\phi₁(t))⋅cos(\phi₂(t))⋅──(\phi₁(t))⋅──(\phi₂(t))   1.0⋅l
#   ⎠                                          dt           dt
# ──────── - ─────────────────────────────────────────────────────────── + ─────
#                                   2
# .0⋅l₁⋅m₂     1.0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₁⋅m₂         1
#
#
#                                  d            d
# ₂⋅m₂⋅sin(\phi₂(t))⋅cos(\phi₁(t))⋅──(\phi₁(t))⋅──(\phi₂(t))
#                                  dt           dt
# ──────────────────────────────────────────────────────────
#                     2
# .0⋅l₁⋅m₁ - l₁⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₁⋅m₂

# %%
sols[phi2_dd]
# Out:
#
#
#
#         g⋅m₁⋅cos(\phi₁(t) - \phi₂(t))⋅cos(\phi₁(t))                          1
# - ─────────────────────────────────────────────────────── + ──────────────────
#                        2
#   1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂   1.0⋅l₂⋅m₁ - l₂⋅m₂⋅
#
#
#
#
# .0⋅g⋅m₁⋅cos(\phi₂(t))                         g⋅m₂⋅cos(\phi₁(t) - \phi₂(t))⋅co
# ───────────────────────────────────── - ──────────────────────────────────────
#    2                                                         2
# cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂   1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi
#
#
#
#
# s(\phi₁(t))                          1.0⋅g⋅m₂⋅cos(\phi₂(t))
# ───────────────── + ─────────────────────────────────────────────────────── +
#                                          2
# ₂(t)) + 1.0⋅l₂⋅m₂   1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂
#
#                                                     2
#                                       ⎛d           ⎞
#    1.0⋅l₁⋅m₁⋅sin(\phi₁(t) - \phi₂(t))⋅⎜──(\phi₁(t))⎟      l₁⋅m₁⋅sin(\phi₁(t) -
#                                       ⎝dt          ⎠
# ─────────────────────────────────────────────────────── - ────────────────────
#                      2
# 1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂   1.0⋅l₂⋅m₁ - l₂⋅m₂⋅co
#
#
#            d            d                                                    d
#  \phi₂(t))⋅──(\phi₁(t))⋅──(\phi₂(t))   1.0⋅l₁⋅m₁⋅sin(\phi₁(t))⋅cos(\phi₂(t))⋅─
#            dt           dt                                                   d
# ──────────────────────────────────── + ───────────────────────────────────────
#  2                                                              2
# s (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂        1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \
#
#
#             d                                                d            d
# ─(\phi₁(t))⋅──(\phi₂(t))   l₁⋅m₁⋅sin(\phi₂(t))⋅cos(\phi₁(t))⋅──(\phi₁(t))⋅──(\
# t           dt                                               dt           dt
# ──────────────────────── - ───────────────────────────────────────────────────
#                                                   2
# phi₂(t)) + 1.0⋅l₂⋅m₂         1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0
#
#                                                                2
#                                                  ⎛d           ⎞
# phi₂(t))      1.0⋅l₁⋅m₂⋅sin(\phi₁(t) - \phi₂(t))⋅⎜──(\phi₁(t))⎟      l₁⋅m₂⋅sin
#                                                  ⎝dt          ⎠
# ──────── + ─────────────────────────────────────────────────────── - ─────────
#                                 2
# ⋅l₂⋅m₂     1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂   1.0⋅l₂⋅m₁
#
#
#                       d            d
# (\phi₁(t) - \phi₂(t))⋅──(\phi₁(t))⋅──(\phi₂(t))   1.0⋅l₁⋅m₂⋅sin(\phi₁(t))⋅cos(
#                       dt           dt
# ─────────────────────────────────────────────── + ────────────────────────────
#             2                                                              2
#  - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂        1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\
#
#
#           d            d                                                d
# \phi₂(t))⋅──(\phi₁(t))⋅──(\phi₂(t))   l₁⋅m₂⋅sin(\phi₂(t))⋅cos(\phi₁(t))⋅──(\ph
#           dt           dt                                               dt
# ─────────────────────────────────── - ────────────────────────────────────────
#                                                              2
# phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂         1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi
#
#
#        d
# i₁(t))⋅──(\phi₂(t))   l₂⋅m₂⋅sin(\phi₁(t) - \phi₂(t))⋅cos(\phi₁(t) - \phi₂(t))⋅
#        dt
# ─────────────────── - ────────────────────────────────────────────────────────
#                                                         2
# ₂(t)) + 1.0⋅l₂⋅m₂                  1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(t))
#
#
# d            d
# ──(\phi₁(t))⋅──(\phi₂(t))   1.0⋅l₂⋅m₂⋅sin(\phi₁(t) - \phi₂(t))⋅cos(\phi₁(t) -
# dt           dt
# ───────────────────────── + ──────────────────────────────────────────────────
#                                                            2
#  + 1.0⋅l₂⋅m₂                          1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) - \phi₂(
#
#                         2
#           ⎛d           ⎞
# \phi₂(t))⋅⎜──(\phi₂(t))⎟    1.0⋅l₂⋅m₂⋅sin(\phi₁(t))⋅cos(\phi₁(t) - \phi₂(t))⋅c
#           ⎝dt          ⎠
# ───────────────────────── + ──────────────────────────────────────────────────
#                                                                  2
# t)) + 1.0⋅l₂⋅m₂                             1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (\phi₁(t) -
#
#
#              d            d
# os(\phi₂(t))⋅──(\phi₁(t))⋅──(\phi₂(t))   l₂⋅m₂⋅sin(\phi₂(t))⋅cos(\phi₁(t) - \p
#              dt           dt
# ────────────────────────────────────── - ─────────────────────────────────────
#                                                                             2
# \phi₂(t)) + 1.0⋅l₂⋅m₂                                  1.0⋅l₂⋅m₁ - l₂⋅m₂⋅cos (
#
#
#                       d            d
# hi₂(t))⋅cos(\phi₁(t))⋅──(\phi₁(t))⋅──(\phi₂(t))
#                       dt           dt
# ───────────────────────────────────────────────
#
# \phi₁(t) - \phi₂(t)) + 1.0⋅l₂⋅m₂
